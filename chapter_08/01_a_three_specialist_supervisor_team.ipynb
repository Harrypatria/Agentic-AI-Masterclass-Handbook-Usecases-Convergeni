# %% [markdown]
# # Chapter 8: Advanced Agent Architectures, Multi-Agent Orchestration
#
# Hands-On: A Three-Specialist Supervisor Team, Adapted from a Real Project
#
# Extracted from: chapter_08_multi_agent.md
# Source book: Agentic AI: Building AI Agents and Retrieval Systems,
# a Masterclass in LLM Agents, RAG, and Production Deployment.
#
# Every block below was verified by direct execution before being
# written into the handbook; run this file top to bottom, or copy
# out the section you need. Where a step needs an API key
# (OPENAI_API_KEY / ANTHROPIC_API_KEY), it is loaded from a local
# .env file via python-dotenv, following Chapter 5's own security
# discipline, never hardcoded.

# %% [markdown]
# ## Installation
#
# Run this once per environment before the cells below.

# %%
# %pip install -q phidata python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv()  # picks up OPENAI_API_KEY / ANTHROPIC_API_KEY / COHERE_API_KEY from the project's .env
# Out:
# True

# %% [markdown]
# **Step 1: Define each specialist with a distinct role and distinct instructions.**

# %%
from phi.agent import Agent
from phi.model.openai import OpenAIChat

researcher = Agent(
    name="Legal Researcher",
    role="Legal research specialist",
    model=OpenAIChat(id="gpt-4o"),
    instructions=[
        "Find and cite relevant legal cases and precedents",
        "Provide detailed research summaries with sources",
    ],
)

analyst = Agent(
    name="Contract Analyst",
    role="Contract analysis specialist",
    model=OpenAIChat(id="gpt-4o"),
    instructions=[
        "Review contracts thoroughly",
        "Identify key terms and potential issues",
    ],
)

strategist = Agent(
    name="Legal Strategist",
    role="Legal strategy specialist",
    model=OpenAIChat(id="gpt-4o"),
    instructions=[
        "Develop comprehensive legal strategies",
        "Consider both risks and opportunities",
    ],
)

# %% [markdown]
# **Step 2: Define the supervisor, passing the three specialists in as its own `team`.**

# %%
legal_team = Agent(
    name="Legal Team Lead",
    role="Legal team coordinator",
    model=OpenAIChat(id="gpt-4o"),
    team=[researcher, analyst, strategist],
    instructions=[
        "Coordinate analysis between team members",
        "Provide comprehensive responses",
        "Ensure all recommendations are properly sourced",
    ],
    show_tool_calls=True,
)

# %% [markdown]
# **Step 3: Send one query to the supervisor and let it route the work.**

# %%
response = legal_team.run(
    "Review this vendor contract for termination clauses and recommend a negotiation strategy."
)
print(response.content)
# Out:
# Running:
#  - transfer_task_to_contract_analyst(task_description=Review a vendor contract for termination clauses., expected_output=..., additional_information=The goal is to assess the flexibility and risks associated with terminating the contract.)
#  - transfer_task_to_legal_strategist(task_description=Formulate a negotiation strategy based on the termination clauses of a vendor contract., expected_output=..., additional_information=Focus on minimizing risks and ensuring favorable terms for the client.)
#
# Based on the detailed analyses from both our contract analyst and legal strategist, here are our findings and recommendations regarding the termination clauses of your vendor contract and a suggested negotiation strategy:
#
# ### Termination Clause Analysis
# 1. **Key Terms:**
#    - **Termination for Convenience**: Provides flexibility, but ensure the notice period is not overly restrictive.
#    - **Termination for Cause**: Clearly defines breach and includes a cure period, which allows addressing defaults before termination.
#    - **Effect of Termination**: Must clearly state post-termination responsibilities.
#    - **Survival Clauses**: Important provisions should remain effective post-termination, such as confidentiality.
#
# 2. **Strengths:**
#    - Provides flexibility and fairness with specified grounds for termination.
#    - Detailed notice and cure periods ensure transparency.
#
# 3. **Weaknesses:**
#    - Ambiguities can lead to disputes; terms such as "failure to perform" need clarity.
#    - Long notice periods might be disadvantageous.
#
# 4. **Potential Issues:**
#    - Ambiguous language and heavy penalties for early termination should be addressed.
#    - Compliance clauses need to be updated for evolving legal standards.
#
# 5. **Recommendations for Clause Optimization:**
#    - Clarify terms to avoid ambiguity and disputes.
#    - Balance termination options to protect both parties.
#
# ### Negotiation Strategy
#
# 1. **Contract Review and Clarity:**
#    - Ensure all terms are clearly defined. Negotiate to improve ambiguous language and address penalties.
#
# 2. **Align with Client Objectives:**
#    - Understand the client’s long-term goals, ensuring flexibility works with business continuity and scalability.
#
# 3. **Risk Mitigation:**
#    - Develop a defined exit strategy including performance metrics that allow termination without penalty.
#
# 4. **Propose Types of Termination:**
#    - Improve the “Termination for Convenience” clause to ensure minimal financial impact and smooth transition.
#
# 5. **Assignment Clauses:**
#    - Negotiating flexible clauses aids in potential industry or strategy shifts.
#
# 6. **Notice and Cure Periods:**
#    - Adjust notice periods to balance response time with business needs.
#
# 7. **Termination Assistance Services:**
#    - Ensure the vendor supports a seamless transition with specified service levels.
#
# 8. **Limitation of Liability:**
#    - Ensure indemnity clauses cap financial exposure effectively.
#
# 9. **Market Leverage:**
#    - Use market data and alternatives to strengthen negotiation, pushing terms to industry benchmarks.
#
# 10. **Legal Trends:**
#     - Reference legal precedents and updates to enforce robust and compliant agreement structures.
#
# By focusing on these strategic points, you can craft a robust negotiation framework that minimizes risks and enhances the client’s operational agility, ensuring favorable terms while minimizing potential liabilities. If you need further assistance with negotiations or implementing these strategies, feel free to reach out!
